# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'F1410A10',
#  'INVOICES 1.xlsx',
#  'INVOICES.xlsx',
#  'RHINO WATCH INVOICES AMOUNT OUTLIER DETECTION.ipynb',
#  'Untitled.ipynb',
#  'weights.xlsx',
#  '~$INVOICES 1.xlsx']

# %%
dt = pd.read_excel("INVOICES 1.xlsx",sheet_name=0)

# %%
df = pd.ExcelFile("INVOICES 1.xlsx")
print(df.sheet_names)
# Out:
# [' anlysis_DS', ' OUTLIER', 'empty_sheet']

# %%
dt = pd.read_excel(df,' anlysis_DS',
                  skiprows = 2
                  )
dt.iloc[5:,:]
# Out:
#                     DATE        INVOICE NO.                CLIENT NAME  \
# 5    2021-05-03 00:00:00   RECHNUNG 46-2021                  FOTOREISE
# 6              17/2/2021                NaN                   GREENBEL
# 7             14/10/2020     RECHNUNG 33.21           STEPHANIE MULLER
# 8              29/4/2021        199-RW-2021             BRITTA GITTING
# 9    2020-01-10 00:00:00         26-RW-2021  BABETTE VALENTINA BRENNER
# ..                   ...                ...                        ...
# 97   2021-10-04 00:00:00        419-RW-2021               KENPUR231221
# 98   2021-08-18 00:00:00        239-RW-2021    BEATE AND LOTHAR KRUSKA
# 99   2021-06-04 00:00:00  RECHNUNG 139-2021                    ANDREA
# 100  2021-09-22 00:00:00     T-202109-15135     THORSTEN SVEN MUSCHLER
# 101                  NaN                NaN                        NaN
#
#      INV. AMOUNT(EURO)  INV. AMOUNT(USD)          DATE BANKED ACCOUNT BANKED  \
# ...

# %%
dt['DATE'] = [str(i).replace("//","/") for i in dt['DATE']]
dt['DATE'] = pd.DatetimeIndex(dt['DATE'])
dt['INV. AMOUNT(EURO)'] = [float(str(i).replace('EUROS','0')) for i in dt['INV. AMOUNT(EURO)']]
dt['INV. AMOUNT(USD)'] = [float(str(i).replace('EUROS','0')) for i in dt['INV. AMOUNT(USD)']]
dt['SAFARIS'] = [float(str(i).replace(' ','0')) for i in dt['SAFARIS']]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATE                      100 non-null    datetime64[ns]
#  1   INVOICE NO.               99 non-null     object
#  2   CLIENT NAME               101 non-null    object
#  3   INV. AMOUNT(EURO)         9 non-null      float64
#  4   INV. AMOUNT(USD)          101 non-null    float64
#  5   DATE BANKED               77 non-null     object
#  6   ACCOUNT BANKED            101 non-null    object
#  7   ACCOMODATION              101 non-null    float64
#  8   SAFARIS                   100 non-null    float64
#  9   PARK ENTRY FEES           97 non-null     float64
#  10  LOCAL AIR TRAVEL CHARGES  90 non-null     float64
#  11  month                     100 non-null    object
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 9.7+ KB

# %%
month = []
for date in dt['DATE']:
    mon = date.month_name()
    year  = date.year
    month.append(mon)

dt['month'] = month

# %%
dt.columns = [i.strip() for i in dt.columns]

# %%
dy = dt[['DATE','CLIENT NAME','INV. AMOUNT(USD)','ACCOMODATION','SAFARIS','LOCAL AIR TRAVEL CHARGES','month']]
dy['year'] = [i.year for i in dy['DATE']]
dy.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21800\2618322981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dy['year'] = [i.year for i in dy['DATE']]
#         DATE                       CLIENT NAME  INV. AMOUNT(USD)  \
# 0 2020-03-21                    THOMAS BRUNNER           7227.00
# 1 2021-01-26                  SOPHIE WENDLANDT           2966.00
# 2 2020-10-14                       KARIN FROJD           2070.25
# 3 2021-01-22          DOREINE AND VERONIKA JOB           7280.00
# 4 2020-12-25   GABRIELE LEBEL AND IRENE FOSTER           6600.00
#
#    ACCOMODATION  SAFARIS  LOCAL AIR TRAVEL CHARGES     month    year
# 0        4297.0   1400.0                       0.0     March  2020.0
# ...

# %%
# how much do the company make  each year
dy[['ACCOMODATION','SAFARIS','LOCAL AIR TRAVEL CHARGES']].sum()
# Out:
# ACCOMODATION                709973.45
# SAFARIS                     256714.00
# LOCAL AIR TRAVEL CHARGES     52544.09
# dtype: float64

# %%
dy[['ACCOMODATION','SAFARIS','LOCAL AIR TRAVEL CHARGES']].mean()
# Out:
# ACCOMODATION                7029.440099
# SAFARIS                     2567.140000
# LOCAL AIR TRAVEL CHARGES     583.823222
# dtype: float64
